# %% [markdown]
# #Title

# %%
import numpy as np

print("Input the first number")
A = int(input())
print("Input the second number")
B = int(input())

SUM = A + B

print(f"The sum of {A} and {B} is {SUM}")
#print("The sum of {0} and {1} is {2}" .format(A, B, SUM))
# Out:
# Input the first number
# 5
# Input the second number
# 6
# The sum of 5 and 6 is 11

# %%
import numpy as np
print("Input the first number")
A = int(input())
print("Input the second number")
B = int(input())
print("Input the style of execution you require")
C = (input())
if C == "*":
  SUM = A * B
  print("The sum of {0} and {1} is {2}" .format(A, B, SUM))
elif C == "/":
  SUM = A / B
  print("The sum of {0} and {1} is {2}" .format(A, B, SUM))
elif C == "+":
  SUM = A + B
  print("The sum of {0} and {1} is {2}" .format(A, B, SUM))
elif C == "-":
  SUM = A - B
  print("The sum of {0} and {1} is {2}" .format(A, B, SUM))
else:
  print("Invalid input")
# Out:
# Input the first number
# 5
# Input the second number
# 6
# Input the style of execution you require
# *
# The sum of 5 and 6 is 30

# %%
import numpy as np
# Used ChatGPT to shorten it and understand why it used this style
# Read inputs
a = int(input("First number: "))
b = int(input("Second number: "))
op = input("Operation (*, /, +, -): ").strip()

# Map operators to built-in arithmetic via lambdas
ops = {
    '+': lambda x, y: x + y,
    '-': lambda x, y: x - y,
    '*': lambda x, y: x * y,
    '/': lambda x, y: x / y if y != 0 else "Error: can't divide by zero"
}

# Execute and display result
if op in ops:
    result = ops[op](a, b)
    print(f"The result of {a} {op} {b} is {result}")
else:
    print("Invalid operator. Use *, /, +, or -.")
# Out:
# First number: 4
# Second number: 5
# Operation (*, /, +, -): *
# The result of 4 * 5 is 20

# %%
import operator

a = int(input("First number: "))
b = int(input("Second number: "))
op = input("operation (*, /, +, -)").strip()

ops = {
    '*' : operator.mul,
    '/' : operator.truediv,
    '+' : operator.add,
    '-' : operator.sub,
}

if op in ops:
  result = ops[op](a,b)
  #My understanding of print(f') is that it allows for operators to be placed directly into a string without needing to format.
  print(f"The result of {a} {op} {b} is {result}")
else:
  print("Invalid operator. Use *, /, +, or -.")
# Out:
# First number: 7
# Second number: 9
# operation (*, /, +, -)+
# The result of 7 + 9 is 16

# %% [markdown]
# ##Sub-title

# %%
print('3.14')
print(3.14)
# Out:
# 3.14
# 3.14

# %%
print("The itsy bitsy spider\nclimbed up the waterspout.")
print()
print("Down came the rain\nand washed the spider out.")
# Out:
# The itsy bitsy spider
# climbed up the waterspout.
#
# Down came the rain
# and washed the spider out.

# %%
print('My father\'s car is yellow')
# Out:
# My father's car is yellow

# %%
print("\\")
# Out:
# \

# %%
print("The itsy bitsy spider" , "climbed up" , "the waterspout.")
# Out:
# The itsy bitsy spider climbed up the waterspout.

# %%
print("James", "UK", 18, True)
# Out:
# James UK 18 True

# %%
print("The itsy bitsy spider","climbedup","the water spout")
print("the itsy bitsy spider"+"climbed up"+"the waterspout")
# Out:
# The itsy bitsy spider climbedup the water spout
# the itsy bitsy spiderclimbed upthe waterspout

# %%
print(19 + 5)
print(19 - 5)
print(19 * 5)
print(19 / 5)
# Out:
# 24
# 14
# 95
# 3.8

# %%
x = 100
x ** 0.5
# Out:
# 10.0

# %%
myName = "Yusaf"
print (myName)
print(type(myName))
print(len(myName))
# Out:
# Yusaf
# <class 'str'>
# 5

# %% [markdown]
# ###sub-sub-titile

# %%
# prompt: print an example of data analysis code in python

import matplotlib.pyplot as plt
import numpy as np

# Generate some random data
data = np.random.rand(1200)

# Perform a simple analysis (e.g., calculate mean and standard deviation)
mean = np.mean(data)
std_dev = np.std(data)

# Print the results
print(f"Mean of the data: {mean:.2f}")
print(f"Standard deviation of the data: {std_dev:.2f}")

# Create a histogram to visualize the data distribution
plt.hist(data, bins=20)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram of Random Data")
plt.show()
# Out:
# Mean of the data: 0.49
# Standard deviation of the data: 0.29
